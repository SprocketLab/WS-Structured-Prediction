# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# T_pos_rec = [
#     2.4801536081738056,
#     0.8672708442673744,
#     2585.4959894414355,
#     0.819177871569192,
#     0.6446368439228097,
#     0.8508416258504978,
#     0.8511568377535597,
#     0.8497003244942701,
# ]
# T_neg_rec = [
#     0.005464854310743932,
#     2.2136793069248686,
#     0.009841628945963469,
#     0.0054654647622517025,
#     0.005399329907164171,
#     0.005467625317579462,
#     0.0054695536743114,
#     0.005468363855503821
# ] # For theta_star = np.array([0.6, 0.9, 1.0])

T_pos_rec = [
    12.888574867303983,
    0.6425417016759917,
    0.6205452110645457,
    0.6729635399910601,
    0.8398997919348631,
]
T_neg_rec = [
    0.013353963983052712,
    0.0023753236430488025,
    0.0023750782349870416,
    0.0030004805500648112,
    0.0023732796637386407,
] # For theta_star = np.array([0.6, 0.9, 1.0])
ns = [
    100, 
    #500, 
    1_000, 
    #5_000, 
    10_000, 
    #50_000,
    100_000,
    #500_000,
    1_000_000,
    ]

T_pos_rec = np.array(T_pos_rec)
T_neg_rec = np.array(T_neg_rec)
ns = np.array(ns)

# %%
plt.figure(figsize=(5, 5))
plt.plot(ns, T_pos_rec, label=r'$\mathbf{\hat{T}}^+$')
plt.plot(ns, T_neg_rec, label=r'$\mathbf{\hat{T}}^-$')
plt.xscale('log')
plt.xlabel('n')
plt.yscale('log')
plt.ylabel(r'MSE($\mathbf{T}, \mathbf{\hat{T}}$)')
plt.legend(frameon=False)
plt.show()
