# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
T_pos_rec = [
    0.017519827799171234,
    0.004053043046138756,
    0.0016220801120775457,
    0.0010353701240674391,
    0.0005411821367157599,
    6.056755940873912e-05,
    3.0489709555321212e-05,
]
T_neg_rec = [
    0.0004770467609908701,
    0.00012425415926832197,
    4.9973662663799834e-05,
    1.540116929852134e-05,
    7.77242282556552e-06,
    1.833704014720712e-06,
    6.616219414967216e-07,
]
ns = [
    100, 
    500, 
    1_000, 
    5_000, 
    10_000, 
    50_000,
    100_000]

T_pos_rec = np.array(T_pos_rec)
T_neg_rec = np.array(T_neg_rec)
ns = np.array(ns)

# %%
plt.figure(figsize=(5, 5))
plt.plot(ns, T_pos_rec, label=r'$\mathbf{\hat{T}}^+$')
plt.plot(ns, T_neg_rec, label=r'$\mathbf{\hat{T}}^-$')
plt.xscale('log')
plt.xlabel('n')
plt.yscale('log')
plt.ylabel(r'MSE($\mathbf{T}, \mathbf{\hat{T}}$)')
plt.legend(frameon=False)
plt.show()
